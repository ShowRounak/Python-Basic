# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna() #deletes all rows containing NaN values
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# but this won't change the original dataframe permanently. 
# For that we use inplace = True parameter. By default it sets to False

df.dropna(inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# axis = 0 means row-wise operations
# axis = 1 means col wise operations

df.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# - Age column has 177 NaN values
# - Cabin has 687 NaN values
# - Embarked has 2 NaN values

# %% [markdown]
# drop columns which has more than 10 NaN records

# %%
df.dropna(axis = 1, thresh=800) #thresh = 800 means it is looking for 800 Not-NaN values
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %% [raw]
# There's another parameter in dropna method, called how
#
# how : {'any', 'all'}, default 'any'
#     Determine if row or column is removed from DataFrame, when we have
#     at least one NA or all NA.
#
#     * 'any' : If any NA values are present, drop that row or column.
#     * 'all' : If all values are NA, drop that row or column.

# %%
df.dropna(axis = 0, how = 'all')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Filled/replace NaN values with any values

df.fillna(value='rik')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Whenever we have NaN values in Age col, replace it with average of age

df.fillna(value=df['Age'].mean())
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.groupby('Survived').describe()['PassengerId']
# Out:
#           count        mean         std  min     25%    50%    75%    max
# Survived
# 0         549.0  447.016393  260.640469  1.0  211.00  455.0  675.0  891.0
# 1         342.0  444.368421  252.358840  2.0  250.75  439.5  651.5  890.0

# %%
# transpose operation

df.groupby('Survived').describe()['PassengerId'].T
# Out:
# Survived           0           1
# count     549.000000  342.000000
# mean      447.016393  444.368421
# std       260.640469  252.358840
# min         1.000000    2.000000
# 25%       211.000000  250.750000
# 50%       455.000000  439.500000
# 75%       675.000000  651.500000
# max       891.000000  890.000000

# %%
df1 = pd.read_csv('C:\\Users\\rouna\\Downloads\\bank\\bank.csv', sep = ';')

# %%
df1
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
l = []

for i in df1['education'].unique():
    l.append(df1[df1['education']==i])

# %%
l
# Out:
# [      age            job   marital education default  balance housing loan  \
#  0      30     unemployed   married   primary      no     1787      no   no
#  9      43       services   married   primary      no      -88     yes  yes
#  18     25    blue-collar    single   primary      no     -221     yes   no
#  26     55    blue-collar   married   primary      no      627     yes   no
#  36     78        retired  divorced   primary      no      229      no   no
#  ...   ...            ...       ...       ...     ...      ...     ...  ...
#  4480   23    blue-collar   married   primary      no     1158     yes   no
#  4485   53    blue-collar   married   primary      no      238     yes   no
#  4486   37    blue-collar   married   primary      no      378     yes   no
#  4499   45    blue-collar  divorced   primary      no      942      no   no
#  4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
df2 = l[0]

# %%
df3 = l[1]

# %%
df2
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
df3
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
df2 = df2.head()[['age', 'job','marital']]

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df3 = df3.head()[['age', 'job','marital']]

# %%
df3
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
pd.concat([df2,df3]) # row wise concatanation
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced
# 1    33     services   married
# 4    59  blue-collar   married
# 7    39   technician   married
# 10   39     services   married
# 11   43       admin.   married

# %%
df5 = pd.concat([df2,df3], axis=1) #column wise concatanation

# %%
df5
# Out:
#      age          job   marital   age          job  marital
# 0   30.0   unemployed   married   NaN          NaN      NaN
# 9   43.0     services   married   NaN          NaN      NaN
# 18  25.0  blue-collar    single   NaN          NaN      NaN
# 26  55.0  blue-collar   married   NaN          NaN      NaN
# 36  78.0      retired  divorced   NaN          NaN      NaN
# 1    NaN          NaN       NaN  33.0     services  married
# 4    NaN          NaN       NaN  59.0  blue-collar  married
# 7    NaN          NaN       NaN  39.0   technician  married
# 10   NaN          NaN       NaN  39.0     services  married
# 11   NaN          NaN       NaN  43.0       admin.  married

# %%
df5['age']
# Out:
#      age   age
# 0   30.0   NaN
# 9   43.0   NaN
# 18  25.0   NaN
# 26  55.0   NaN
# 36  78.0   NaN
# 1    NaN  33.0
# 4    NaN  59.0
# 7    NaN  39.0
# 10   NaN  39.0
# 11   NaN  43.0

# %%
#iloc = integer location

df5.iloc[: ,3] # all rows, column index
# Out:
# 0      NaN
# 9      NaN
# 18     NaN
# 26     NaN
# 36     NaN
# 1     33.0
# 4     59.0
# 7     39.0
# 10    39.0
# 11    43.0
# Name: age, dtype: float64

# %%
df5.iloc[[5,6], [3,4]]
# Out:
#     age          job
# 1  33.0     services
# 4  59.0  blue-collar

# %%
df5.loc[[9,10],['age']]
# Out:
#      age   age
# 9   43.0   NaN
# 10   NaN  39.0

# %% [markdown]
# loc always takes the named one and iloc always takes the in-built or default one

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df2.loc[[9,18],['job', 'marital']]
# Out:
#             job  marital
# 9      services  married
# 18  blue-collar   single

# %%
df2.iloc[[1,2],[1,2]]
# Out:
#             job  marital
# 9      services  married
# 18  blue-collar   single

# %%
df2.loc[[9,18], ['age', 'marital']]
# Out:
#     age  marital
# 9    43  married
# 18   25   single

# %%
df2.iloc[[1,2],[0,2]]
# Out:
#     age  marital
# 9    43  married
# 18   25   single

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df3
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
# merge operation

pd.merge(df2,df3, on='age') #by default how = inner
# Out:
#    age     job_x marital_x   job_y marital_y
# 0   43  services   married  admin.   married

# %%
pd.merge(df2,df3, on='age', how='left')
# Out:
#    age        job_x marital_x   job_y marital_y
# 0   30   unemployed   married     NaN       NaN
# 1   43     services   married  admin.   married
# 2   25  blue-collar    single     NaN       NaN
# 3   55  blue-collar   married     NaN       NaN
# 4   78      retired  divorced     NaN       NaN

# %%
pd.merge(df2,df3, on='age', how='right')
# Out:
#    age     job_x marital_x        job_y marital_y
# 0   33       NaN       NaN     services   married
# 1   59       NaN       NaN  blue-collar   married
# 2   39       NaN       NaN   technician   married
# 3   39       NaN       NaN     services   married
# 4   43  services   married       admin.   married

# %%
pd.merge(df2,df3, on='age', how='outer')
# Out:
#    age        job_x marital_x        job_y marital_y
# 0   30   unemployed   married          NaN       NaN
# 1   43     services   married       admin.   married
# 2   25  blue-collar    single          NaN       NaN
# 3   55  blue-collar   married          NaN       NaN
# 4   78      retired  divorced          NaN       NaN
# 5   33          NaN       NaN     services   married
# 6   59          NaN       NaN  blue-collar   married
# 7   39          NaN       NaN   technician   married
# 8   39          NaN       NaN     services   married

# %%
df2.join(df3,on='age')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 df2.join(df3,on='age')
#
# File ~\anaconda3\envs\DataScienceBootcamp\lib\site-packages\pandas\core\frame.py:9976, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9813 def join(
#    9814     self,
#    9815     other: DataFrame | Series | list[DataFrame | Series],
#    (...)
#    9821     validate: str | None = None,
#    9822 ) -> DataFrame:
#    9823     """
#    9824     Join columns of another DataFrame.
#    9825
#    (...)
#    9974     5  K1  A5   B1
#    9975     """
# -> 9976     return self._join_compat(
#    9977         other,
#    9978         on=on,
#    9979         how=how,
#    9980         lsuffix=lsuffix,
#    9981         rsuffix=rsuffix,
#    9982         sort=sort,
#    9983         validate=validate,
#    9984     )
#
# ...

# %% [markdown]
# We have to rename column

# %%
df2 = df2.set_index('age')
df2
# Out:
#              job   marital
# age
# 30    unemployed   married
# 43      services   married
# 25   blue-collar    single
# 55   blue-collar   married
# 78       retired  divorced

# %%
df2.rename(columns={'job':'job1','marital':'marital1'}, inplace=True)

# %%
df3 = df3.set_index('age')
df3
# Out:
#              job  marital
# age
# 33      services  married
# 59   blue-collar  married
# 39    technician  married
# 39      services  married
# 43        admin.  married

# %%
df2.join(df3,on='age') # by default how is left
# Out:
#             job1  marital1     job  marital
# age
# 30    unemployed   married     NaN      NaN
# 43      services   married  admin.  married
# 25   blue-collar    single     NaN      NaN
# 55   blue-collar   married     NaN      NaN
# 78       retired  divorced     NaN      NaN

# %%
df2.join(df3,on='age', how='inner')
# Out:
#          job1 marital1     job  marital
# age
# 43   services  married  admin.  married

# %%
pd.merge(df2,df3)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 pd.merge(df2,df3)
#
# File ~\anaconda3\envs\DataScienceBootcamp\lib\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
# ...

# %%
pd.merge(df2,df3, left_on='job1', right_on='job')
# Out:
#           job1 marital1          job  marital
# 0     services  married     services  married
# 1     services  married     services  married
# 2  blue-collar   single  blue-collar  married
# 3  blue-collar  married  blue-collar  married

# %%
df2.join(df3)
# Out:
#             job1  marital1     job  marital
# age
# 25   blue-collar    single     NaN      NaN
# 30    unemployed   married     NaN      NaN
# 43      services   married  admin.  married
# 55   blue-collar   married     NaN      NaN
# 78       retired  divorced     NaN      NaN

# %%
df2 = df2.reset_index()

# %%
df2
# Out:
#    age         job1  marital1
# 0   30   unemployed   married
# 1   43     services   married
# 2   25  blue-collar    single
# 3   55  blue-collar   married
# 4   78      retired  divorced

# %%
# Dataframe of number of sales made by an employee
sales = {'Tony': 103,
         'Sally': 202,
         'Randy': 380,
         'Ellen': 101,
         'Fred': 82
        }
# Dataframe of all employees and the region they work in
region = {'Tony': 'West',
          'Sally': 'South',
          'Carl': 'West',
          'Archie': 'North',
          'Randy': 'East',
          'Ellen': 'South',
          'Fred': np.nan,
          'Mo': 'East',
          'HanWei': np.nan,
         }

# %%
sales_df = pd.DataFrame.from_dict(sales, orient='index', 
                                  columns=['sales'])
region_df = pd.DataFrame.from_dict(region, orient='index', 
                                   columns=['region'])

# %%
sales_df
# Out:
#        sales
# Tony     103
# Sally    202
# Randy    380
# Ellen    101
# Fred      82

# %%
region_df
# Out:
#        region
# Tony     West
# Sally   South
# Carl     West
# Archie  North
# Randy    East
# Ellen   South
# Fred      NaN
# Mo       East
# HanWei    NaN

# %%
region_df.join(sales_df)
# Out:
#        region  sales
# Tony     West  103.0
# Sally   South  202.0
# Carl     West    NaN
# Archie  North    NaN
# Randy    East  380.0
# Ellen   South  101.0
# Fred      NaN   82.0
# Mo       East    NaN
# HanWei    NaN    NaN

# %%
region_df.join(sales_df, how= 'inner')
# Out:
#       region  sales
# Tony    West    103
# Sally  South    202
# Randy   East    380
# Ellen  South    101
# Fred     NaN     82

# %%
joined_df_merge = region_df.merge(sales_df, how='left', 
                                      left_index=True,
                                      right_index=True)

# %%
joined_df_merge
# Out:
#        region  sales
# Tony     West  103.0
# Sally   South  202.0
# Carl     West    NaN
# Archie  North    NaN
# Randy    East  380.0
# Ellen   South  101.0
# Fred      NaN   82.0
# Mo       East    NaN
# HanWei    NaN    NaN

# %%
grouped_df = joined_df_merge.groupby(by='region').sum()

print(grouped_df)
# Out:
#         sales
# region
# East    380.0
# North     0.0
# South   303.0
# West    103.0

# %%
grouped_df.reset_index(inplace=True)

print(grouped_df)
# Out:
#   region  sales
# 0   East  380.0
# 1  North    0.0
# 2  South  303.0
# 3   West  103.0

# %% [raw]
# Now let’s merge joined_df_merge with grouped_df using the region column. We have to specify a suffix because both of our dataframes (that we are merging) contain a column called sales. The suffixes input appends the specified strings to the labels of columns that have identical names in both dataframes. In our case, since the second dataframe’s sales column is actually sales for the entire region, we can append “_region” to its label to make clear.

# %%
employee_contrib = joined_df_merge.merge(grouped_df, how='left', 
                                         left_on='region', 
                                         right_on='region',
                                         suffixes=('','_region'))
print(employee_contrib)
# Out:
#   region  sales  sales_region
# 0   West  103.0         103.0
# 1  South  202.0         303.0
# 2   West    NaN         103.0
# 3  North    NaN           0.0
# 4   East  380.0         380.0
# 5  South  101.0         303.0
# 6    NaN   82.0           NaN
# 7   East    NaN         380.0
# 8    NaN    NaN           NaN

# %% [raw]
# Oh no, our index disappeared! But we can use set_index to get it back (otherwise we won’t know which employee each row corresponds to.

# %%
employee_contrib = employee_contrib.set_index(joined_df_merge.index)
print(employee_contrib)
# Out:
#        region  sales  sales_region
# Tony     West  103.0         103.0
# Sally   South  202.0         303.0
# Carl     West    NaN         103.0
# Archie  North    NaN           0.0
# Randy    East  380.0         380.0
# Ellen   South  101.0         303.0
# Fred      NaN   82.0           NaN
# Mo       East    NaN         380.0
# HanWei    NaN    NaN           NaN

# %%
# drop NaN from the region

employee_contrib = employee_contrib.dropna(subset='region')

# %%
employee_contrib
# Out:
#        region  sales  sales_region
# Tony     West  103.0         103.0
# Sally   South  202.0         303.0
# Carl     West    NaN         103.0
# Archie  North    NaN           0.0
# Randy    East  380.0         380.0
# Ellen   South  101.0         303.0
# Mo       East    NaN         380.0

# %%
#fill NaN values with zero

employee_contrib = employee_contrib.fillna(0)

# %%
employee_contrib
# Out:
#        region  sales  sales_region
# Tony     West  103.0         103.0
# Sally   South  202.0         303.0
# Carl     West    0.0         103.0
# Archie  North    0.0           0.0
# Randy    East  380.0         380.0
# Ellen   South  101.0         303.0
# Mo       East    0.0         380.0

# %%
# percentage of sales

employee_contrib['%_of_sales'] = employee_contrib['sales']/employee_contrib['sales_region']

employee_contrib
# Out:
#        region  sales  sales_region  %_of_sales
# Tony     West  103.0         103.0    1.000000
# Sally   South  202.0         303.0    0.666667
# Carl     West    0.0         103.0    0.000000
# Archie  North    0.0           0.0         NaN
# Randy    East  380.0         380.0    1.000000
# Ellen   South  101.0         303.0    0.333333
# Mo       East    0.0         380.0    0.000000

# %%
# sorting by region and %_of_sales

employee_contrib.sort_values(by=['region','%_of_sales'],inplace=True)

employee_contrib
# Out:
#        region  sales  sales_region  %_of_sales
# Mo       East    0.0         380.0    0.000000
# Randy    East  380.0         380.0    1.000000
# Archie  North    0.0           0.0         NaN
# Ellen   South  101.0         303.0    0.333333
# Sally   South  202.0         303.0    0.666667
# Carl     West    0.0         103.0    0.000000
# Tony     West  103.0         103.0    1.000000

# %% [markdown]
# ### Difference between join and merge
#
#
# - We can use join and merge to combine 2 dataframes.
# - The join method works best when we are joining dataframes on their indexes (though you can specify another column to join on for the left dataframe).
# - The merge method is more versatile and allows us to specify columns besides the index to join on for both dataframes. If the index gets reset to a counter post merge, we can use set_index to change it back.
