# %%
import pandas as pd

# %%
pip install lxml
# Out:
# ...
#      ---------------------------------------- 3.9/3.9 MB 2.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#read_html only collects data from a website which is tabular in format

df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df1.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [5 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1[['Age', 'GS']]
# Out:
#     Age  GS
# 0    24  22
# 1    20   0
# 2    21  67
# 3    28   0
# 4    29  72
# ..   ..  ..
# 670  26  68
# 671  26  48
# 672  26  20
# 673  22  45
# 674  25  59
#
# [675 rows x 2 columns]

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df1.to_csv('NBA.csv', index=False)

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is D0C1-5A67
#
#  Directory of C:\Users\rouna
#
# 21-12-2022  20:34    <DIR>          .
# 22-10-2022  16:10    <DIR>          ..
# 21-12-2022  20:34    <DIR>          .conda
# 21-10-2022  16:03                25 .condarc
# 05-11-2022  15:57    <DIR>          .continuum
# 21-12-2022  20:04    <DIR>          .ipynb_checkpoints
# 19-10-2022  19:43    <DIR>          .ipython
# 20-11-2022  17:05    <DIR>          .jupyter
# 13-11-2022  01:31    <DIR>          .matplotlib
# 12-11-2022  00:02    <DIR>          .ms-ad
# 18-11-2022  19:24    <DIR>          __pycache__
# 12-11-2022  17:37            33,491 12th November iNeuron.ipynb
# 13-11-2022  17:26            25,890 13th November iNeuron.ipynb
# 11-12-2022  16:22    <DIR>          19.3 MongoDB
# 21-11-2022  18:25            55,345 19th November iNeuron (Imran).ipynb
# 01-11-2022  18:41            22,102 1st Oct ineuron(operators, if-else).ipynb
# ...

# %%
l = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
len(l)
# Out:
# 3

# %% [markdown]
# So, there are 3 tables in the website

# %%
l[0]
# Out:
#                Player       Span  Mat Inns  NO  Runs   HS    Ave   BF      SR  \
# 0          AB Agarkar  2006-2007    4    2   0    15   14   7.50   11  136.36
# 1            KK Ahmed  2018-2019   14    1   1     1   1*      -    1  100.00
# 2           S Aravind  2015-2015    1    -   -     -    -      -    -       -
# 3      Arshdeep Singh  2022-2022   21    4   4     6   2*      -    4  150.00
# 4            R Ashwin  2010-2022   65   19  12   184  31*  26.28  160  115.00
# ..                ...        ...  ...  ...  ..   ...  ...    ...  ...     ...
# 94      R Vinay Kumar  2010-2013    9    1   1     2   2*      -    4   50.00
# 95  Washington Sundar  2017-2022   32   12   4    47  14*   5.87   33  142.42
# 96           SA Yadav  2021-2022   42   40   8  1408  117  44.00  778  180.97
# 97           UT Yadav  2012-2022    9    2   1    22  20*  22.00   21  104.76
# 98       Yuvraj Singh  2007-2017   58   51   9  1177  77*  28.02  863  136.38
#
#    100  50  0   4s  6s
# ...

# %%
l[1]
# Out:
#                                                    0
# 0  By default, the shading indicates records from...
# 1  Adjust:  most recent  | past week  | past mont...

# %%
l[2]
# Out:
#                                                    0
# 0  Records includes the following current or rece...
# 1  New Zealand v India at Napier, 3rd T20I, Nov 2...
# 2  New Zealand v India at Mount Maunganui, 2nd T2...
# 3  England v India at Adelaide, ICC Men's T20 Wor...

# %%
l[0].to_csv('cricketinfo.csv', index = False)

# %% [markdown]
# ## Convert JSON to DataFrame (Tabular Format)

# %%
d = """
{"name":"rik",
"emailid":"rikbale@gmail.com",
"platform":["ineuron","techneuron","kidsneuron"]
}
"""

# %%
type(d)
# Out:
# str

# %%
pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 pd.DataFrame(d)
#
# File ~\anaconda3\envs\DataScienceBootcamp\lib\site-packages\pandas\core\frame.py:780, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     777 # For data is scalar
#     778 else:
#     779     if index is None or columns is None:
# --> 780         raise ValueError("DataFrame constructor not properly called!")
#     782     index = ensure_index(index)
#     783     columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!

# %%
import json

# %%
result = json.loads(d)

# %%
result
# Out:
# {'name': 'rik',
#  'emailid': 'rikbale@gmail.com',
#  'platform': ['ineuron', 'techneuron', 'kidsneuron']}

# %%
type(result)
# Out:
# dict

# %%
pd.DataFrame(result)
# Out:
#   name            emailid    platform
# 0  rik  rikbale@gmail.com     ineuron
# 1  rik  rikbale@gmail.com  techneuron
# 2  rik  rikbale@gmail.com  kidsneuron

# %%
 d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
pd.DataFrame(d)
# Out:
#                           packetType  \
# checkEngineLightFlag               D
# batteryVoltageStableTime           D
# batteryVoltageStable               D
# batteryVoltageOff                  D
# batteryCrankParamTN                D
# batteryCrankParamVN                D
# batteryCrankParamTP                D
# batteryCrankParamVP                D
# batteryCrankParamTT                D
# batteryCrankParamV0                D
# batteryVoltageMaxOn                D
# batteryVoltageMinOn                D
# batteryVoltageMaxOff               D
# batteryVoltageMinOff               D
# batteryVoltageOnAverage            D
# engineLoadMax                      D
# engineLoadAverage                  D
# rpmMax                             D
# rpmAverage                         D
# gpsSpeedAverage                    D
# vssMax                             D
# vssAverage                         D
# tcuTemperatureMin                  D
# tcuTemperatureMax                  D
# ...

# %%
d1 = d['data']

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
# ...

# %%
#remove 'diagnosticTroubleCodeData': []

d1.pop('diagnosticTroubleCodeData')
# Out:
# []

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
# ...

# %%
pd.DataFrame(d1)
# Out:
#   checkEngineLightFlag  batteryVoltageStableTime batteryVoltageStable  \
# 0                    F                         0                    0
# 1                    F                         0                    0
# 2                    F                         0                    0
# 3                    F                         0                    0
#
#   batteryVoltageOff batteryCrankParamTN batteryCrankParamVN  \
# 0             12.42               -0.08                0.00
# 1             12.42               -0.08                0.00
# 2             12.42               -0.08                0.00
# 3             12.42               -0.08                0.00
#
#   batteryCrankParamTP batteryCrankParamVP batteryCrankParamTT  \
# 0               -0.08                0.00            -0.00008
# 1               -0.08                0.00            -0.00008
# 2               -0.08                0.00            -0.00008
# ...

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
d = pd.read_json(url)

# %%
d
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
d['id']
# Out:
# 0     1507803479
# 1     1507777076
# 2     1507564558
# 3     1507101341
# 4     1507017355
# 5     1506997865
# 6     1506936544
# 7     1506776800
# 8     1506751371
# 9     1506628703
# 10    1506568111
# 11    1506555123
# 12    1506529224
# 13    1506302635
# 14    1506298322
# 15    1506070881
# 16    1506004660
# 17    1505803858
# 18    1505800443
# 19    1505615001
# 20    1505392495
# 21    1505293806
# 22    1504959845
# 23    1504657343
# 24    1504592481
# 25    1504585979
# 26    1504108738
# 27    1503750577
# 28    1503697602
# 29    1503604617
# Name: id, dtype: int64

# %%
d['reactions']
# Out:
# 0     {'url': 'https://api.github.com/repos/pandas-d...
# 1     {'url': 'https://api.github.com/repos/pandas-d...
# 2     {'url': 'https://api.github.com/repos/pandas-d...
# 3     {'url': 'https://api.github.com/repos/pandas-d...
# 4     {'url': 'https://api.github.com/repos/pandas-d...
# 5     {'url': 'https://api.github.com/repos/pandas-d...
# 6     {'url': 'https://api.github.com/repos/pandas-d...
# 7     {'url': 'https://api.github.com/repos/pandas-d...
# 8     {'url': 'https://api.github.com/repos/pandas-d...
# 9     {'url': 'https://api.github.com/repos/pandas-d...
# 10    {'url': 'https://api.github.com/repos/pandas-d...
# 11    {'url': 'https://api.github.com/repos/pandas-d...
# 12    {'url': 'https://api.github.com/repos/pandas-d...
# 13    {'url': 'https://api.github.com/repos/pandas-d...
# 14    {'url': 'https://api.github.com/repos/pandas-d...
# 15    {'url': 'https://api.github.com/repos/pandas-d...
# 16    {'url': 'https://api.github.com/repos/pandas-d...
# ...

# %% [markdown]
# ## Get RAW json from URL

# %%
pip install requests
# Out:
# ...
#      ---------------------------------------- 62.8/62.8 kB 1.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 61.5/61.5 kB 3.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1 = data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50393',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50393/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50393/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50393/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50393',
#   'id': 1507803479,
#   'node_id': 'I_kwDOAA0YD85Z30FX',
#   'number': 50393,
#   'title': 'CLN remove _assert_not_frame_equal_both?',
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
# ...

# %%
#no. of unique dictionary in the RAW JSON

len(data1)
# Out:
# 30

# %%
data1[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50393',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50393/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50393/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50393/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/issues/50393',
#  'id': 1507803479,
#  'node_id': 'I_kwDOAA0YD85Z30FX',
#  'number': 50393,
#  'title': 'CLN remove _assert_not_frame_equal_both?',
#  'user': {'login': 'MarcoGorelli',
#   'id': 33491632,
#   'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/MarcoGorelli',
#   'html_url': 'https://github.com/MarcoGorelli',
#   'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
# ...

# %%
data1[0].keys()
# Out:
# dict_keys(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url', 'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels', 'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments', 'created_at', 'updated_at', 'closed_at', 'author_association', 'active_lock_reason', 'body', 'reactions', 'timeline_url', 'performed_via_github_app', 'state_reason'])

# %%
data1[0]['user']
# Out:
# {'login': 'MarcoGorelli',
#  'id': 33491632,
#  'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/MarcoGorelli',
#  'html_url': 'https://github.com/MarcoGorelli',
#  'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#  'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#  'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#  'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#  'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
# ...

# %%
data1[0]['user']['id']
# Out:
# 33491632

# %%
for i in range(len(data1)):
    print(data1[i]['user']['id'])
# Out:
# 33491632
# 33491632
# 51630653
# 10647082
# 10647082
# 47963215
# 10647082
# 33491632
# 45562402
# 61934744
# 33491632
# 33491632
# 33491632
# 61934744
# 4061254
# 10682573
# 11536226
# 10058240
# 10058240
# 8078968
# 7526622
# 33491632
# 91160475
# 33491632
# 1020496
# 33491632
# 8326175
# 10647082
# 61934744
# 10647082

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50393',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50393/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50393/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50393/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50393',
#   'id': 1507803479,
#   'node_id': 'I_kwDOAA0YD85Z30FX',
#   'number': 50393,
#   'title': 'CLN remove _assert_not_frame_equal_both?',
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
# ...

# %%
df2 = pd.DataFrame(data1, columns=['id','url', 'repository_url','labels_url','user'])

# %%
df2.to_csv('json_res.csv')

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is D0C1-5A67
#
#  Directory of C:\Users\rouna
#
# 22-12-2022  18:33    <DIR>          .
# 22-10-2022  16:10    <DIR>          ..
# 22-12-2022  18:33    <DIR>          .conda
# 21-10-2022  16:03                25 .condarc
# 05-11-2022  15:57    <DIR>          .continuum
# 22-12-2022  18:06    <DIR>          .ipynb_checkpoints
# 19-10-2022  19:43    <DIR>          .ipython
# 20-11-2022  17:05    <DIR>          .jupyter
# 13-11-2022  01:31    <DIR>          .matplotlib
# 12-11-2022  00:02    <DIR>          .ms-ad
# 18-11-2022  19:24    <DIR>          __pycache__
# 12-11-2022  17:37            33,491 12th November iNeuron.ipynb
# 13-11-2022  17:26            25,890 13th November iNeuron.ipynb
# 11-12-2022  16:22    <DIR>          19.3 MongoDB
# 21-11-2022  18:25            55,345 19th November iNeuron (Imran).ipynb
# 01-11-2022  18:41            22,102 1st Oct ineuron(operators, if-else).ipynb
# ...

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50393',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50393/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50393/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50393/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50393',
#   'id': 1507803479,
#   'node_id': 'I_kwDOAA0YD85Z30FX',
#   'number': 50393,
#   'title': 'CLN remove _assert_not_frame_equal_both?',
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
# ...

# %%
l = []
for i in range(len(data1)):
    print(data1[0]['user'])
    l.append(data1[0]['user'])
# Out:
# {'login': 'MarcoGorelli', 'id': 33491632, 'node_id': 'MDQ6VXNlcjMzNDkxNjMy', 'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/MarcoGorelli', 'html_url': 'https://github.com/MarcoGorelli', 'followers_url': 'https://api.github.com/users/MarcoGorelli/followers', 'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}', 'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions', 'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs', 'repos_url': 'https://api.github.com/users/MarcoGorelli/repos', 'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}', 'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events', 'type': 'User', 'site_admin': False}
# ...

# %%
l
# Out:
# [{'login': 'MarcoGorelli',
#   'id': 33491632,
#   'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/MarcoGorelli',
#   'html_url': 'https://github.com/MarcoGorelli',
#   'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#   'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#   'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#   'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#   'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
# ...

# %%
df3 = pd.DataFrame(l)

# %%
df3
# Out:
#            login        id               node_id  \
# 0   MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 1   MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 2   MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 3   MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 4   MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 5   MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 6   MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 7   MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 8   MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 9   MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 10  MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 11  MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 12  MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 13  MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 14  MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 15  MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 16  MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 17  MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# ...

# %%
result = pd.concat([df2,df3], axis=1)

# %%
result
# Out:
#             id                                                url  \
# 0   1507803479  https://api.github.com/repos/pandas-dev/pandas...
# 1   1507777076  https://api.github.com/repos/pandas-dev/pandas...
# 2   1507564558  https://api.github.com/repos/pandas-dev/pandas...
# 3   1507101341  https://api.github.com/repos/pandas-dev/pandas...
# 4   1507017355  https://api.github.com/repos/pandas-dev/pandas...
# 5   1506997865  https://api.github.com/repos/pandas-dev/pandas...
# 6   1506936544  https://api.github.com/repos/pandas-dev/pandas...
# 7   1506776800  https://api.github.com/repos/pandas-dev/pandas...
# 8   1506751371  https://api.github.com/repos/pandas-dev/pandas...
# 9   1506628703  https://api.github.com/repos/pandas-dev/pandas...
# 10  1506568111  https://api.github.com/repos/pandas-dev/pandas...
# 11  1506555123  https://api.github.com/repos/pandas-dev/pandas...
# 12  1506529224  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
result.to_csv('pandaassign_user.csv')
